# %%
import pandas as pd

# %%
import io
import sys

    
def replace_bad_character(line):
    return line.strip().replace(u"\u202a", "").replace(u"\u200e", "").replace(u"\u202c", "").replace(u"\xa0", " ")

try: 
    filepath = raw_input("Please input the chat filepath:")
except NameError:
    filepath = input("Please input chat filepath:")

try:
    with io.open(filepath, "r", encoding="utf-8") as file:
        content = [replace_bad_character(l) for l in file.readlines()]
    
except IOError as e:
    print("File \"" + filepath + "\" not found. Please recheck your file location")
    sys.exit()

common_words = []
cw_filepath = ""

cw_option = "Please select common word file or leave it blank to escape: \n\
    1: Indonesian (id_cw.py)\n\
    2: English (en_cw.py)\n\
    3: Custom file\n\
    4: Skip common word\n"
try: 
    cw = raw_input(cw_option)
except NameError:
    cw = input(cw_option)
    
if cw == "1":
    cw_filepath = "id_cw"
elif cw == "2":
    cw_filepath = "en_cw"
elif cw == "3":
    """
    Prompt user to input the file path
    """
    try: 
        cw_filepath = raw_input("Please input your common word filepath")
    except NameError:
        cw_filepath = input("Please input your common word filepath")


if len(cw_filepath) > 0:

    try:
        common_words = __import__(cw_filepath, globals(), locals(), [common_words]).common_words
        
    except:
        print("Error getting common word file location")
        sys.exit()
else:
    print("You skipped common word.")

try: 
    verbose = raw_input("You wanna print the verbose mode? y/[N]: ") == "y" or False
except NameError:
    verbose = input("You wanna print the verbose mode? y/[N]: ") == "y" or False
# Out:
# You skipped common word.

# %%
import re
import errno
import pandas as pd
import emoji
from collections import Counter
from dateutil import parser
import operator
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline


class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
"""
Global vars
"""
chat_of_members = {}
member_chat = {"member": [], "chat_count": []}
attachments = {}
refered_web = {"domain": [], "d_count": []}
popular_words = {}
chat_words = ""
emojis = {"emj_char": [], "char_count": []}
heat_map = {
    "day": [], 
    "hour": [], 
    "chat_count": []
}
deleted_message = 0
pure_chat = ""
total_chat = 0

"""
Starting line mean a line that started with date time.
Because there are multiline chat. I called it following line.
A starting line must be classified before it's data being extracted.
"""
def is_starting_line(line):
    pattern = r"""
        (\[?)       #Zero or one open square bracket '['
        (((\d{1,2})   #1 to 2 digit date
        (/|-)       #'/' or '-' separator
        (\d{1,2})   #1 to 2 digit month
        (/|-)       #'/' or '-' separator
        (\d{2,4}))   #2 to 4 digit of year
        (,?\s)      #Zero or one comma ',' and ingle space
        ((\d{1,2})  #1 to 2 digit of hour
        (:|\.)      #Colon ':' or dot '.' separator
        (\d{2})     #2 digit of minute
        (\.|:)?     #Zero or one of dot '.' or colon ':'
        (\d{2})?    #Zero or one of 2 digits of second
        (\s[AP]M)?))  #Zero or one of ('space', 'A' or 'P', and 'M'
        (\]?\s-?\s?\s?)#Zero or one close square bracket ']', Zero or one (space and '-'), zero or one space
        (.+)        #One or more character of chat member phone number or contact name
    """
    
    return re.match(re.compile(pattern, re.VERBOSE), line)

"""
"Is Chat" means the body of a line is not an event.
May contains attachment
"""
def is_chat(body):
    pattern = r"""
            ([^:]+)#Chat member
            (:)   #Colon separator
            (.+)  #One or more charachter of message content
    """
    
    return re.match(re.compile(pattern, re.VERBOSE), body)

"""
Classify attachment
Note: in Android, there is no proper description wether it's a image, 
      video, audio, gif, or sticker.
"""
def contains_attachment(body):
    pattern_attachment = [
        ".*<Media omitted>$", #English version of android attachment
        ".*<Media tidak disertakan>$", #Indonesia version of android attachment
        ".*Pesan tidak didukung$", #Some device not recognize sticker attachment
        ".+\.vcf \(file\sterlampir\)$", #Indonesian version of android contact card,
        ".+\.vcf \(file\sattached\)$", #Indonesian version of android contact card,
        ".*image omitted$",
        ".*video omitted$",
        ".*document omitted$",
        ".*Contact card omitted$",
        ".*audio omitted$",
        ".*GIF omitted$",
        ".*sticker omitted$"
    ]
    
    for p in pattern_attachment:
        match = re.match(p, body)
        if match:
            return body
    return None

"""
Event means logs of chat activity e.g member left, member added, removed, etc.
This kind of line can not count as a chat
"""
def is_event(body):
    pattern_event = [
        "Messages to this group are now secured with end-to-end encryption\.$",
        ".+\screated this group$",
        ".+\skeluar$",
        ".+\sleft$",
        ".+\stelah bergabung menggunakan tautan undangan grup ini$",
        ".+\smenambahkan\s.+",
        ".+\sadded\s.+",
        ".+\sremoved\s.+",
        ".*You joined using this group's invite links$",
        ".+'s security code changed\.$",
        ".*telah mengganti nomor teleponnya ke nomor baru. Ketuk untuk mengirim pesan atau menambahkan nomor baru\.$",
        ".*changed their phone number to a new number. Tap to message or add the new number\.$"
    ]
    
    for p in pattern_event:
        match = re.match(p, body)
        if match:
            return match
    return None
"""
Deleted message
"""
def is_deleted(body):
    p = [
        ".*This message was deleted\.$",
        ".*Pesan ini telah dihapus$"
    ]
    
    for p in p:
        match = re.match(p, body)
        if match:
            return body
    return None

"""
EXTRACT TIMESTAMP
"""
def extract_timestamp(time_string):
    return parser.parse(time_string)

"""
Check if chat contais a url
"""
def extract_url(body):
    pattern = "https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+"
    
    return re.findall(pattern, body)

def get_domain(str):
    domain = str.replace("http://", '')
    domain = domain.replace("https://", '')
    domain = domain.split("/")
    return domain[0]

"""
EMOJI
"""
def extract_emojis(string):
    emj = []
    for c in string:
        if c in emoji.UNICODE_EMOJI:
            emj.append(c)

    if len(emj) > 0:
        increment_emoji_count(emj)
    
    return emj

"""
Count top words
"""
def get_words(msg):
    
    #remove non alpha content
    regex = re.sub(r"[^a-z\s]+", "", msg.lower())
    regex = re.sub(r'[^\x00-\x7f]',r'', regex)
    words = regex.split(" ")
    
    for x in words:
        if x:
            rank_word(x)
            
    return words

def rank_word(word):
    
    if not word in common_words:
        popular_words[word] = popular_words.get(word, 0) + 1
        global chat_words
        chat_words += " {0}".format(word)
        
    return word
    
"""
Counting function
"""

"""
Rank the 'Most Active user'
"""        
def increment_chat_count(member):
    member_chat["member"].append(member)
    member_chat["chat_count"].append(1)
    global total_chat
    total_chat += 1
    
    return member
 
def increment_attachment_count(message):
    
    if "image omitted" in message:
        attachments["image"] = attachments.get("image", 0) +1
        return
        
    if "video omitted" in message:
        attachments["video"] = attachments.get("video", 0) +1
        return
    
    if "audio omitted" in message:
        attachments["audio"] = attachments.get("audio", 0) +1
        return
    
    if "document omitted" in message:
        attachments["document"] = attachments.get("document", 0) +1
        return
    
    if "Contact card omitted" in message or ".vcf" in message:
        attachments["contact"] = attachments.get("contact", 0) +1
        return
    
    if "GIF omitted" in message:
        attachments["gif"] = attachments.get("gif", 0) +1
        return
    
    if "sticker omitted" in message:
        attachments["sticker"] = attachments.get("sticker", 0) +1
        return
    
    ##Unknown attachment
    attachments["unknown"] = attachments.get("unknown", 0) +1

    

def increment_link_count(urls):
    for url in urls:
        increment_domain_count(get_domain(url))
                    
    return len(urls)
    
def increment_domain_count(domain):
    refered_web["domain"].append(domain)
    refered_web["d_count"].append(1)

def increment_emoji_count(char_list):
    groups = Counter(char_list)
    for c in groups.items():
        emojis["emj_char"].append(c[0])
        emojis["char_count"].append(c[1])
        
def increment_heatmap(dt):
    heat_map["day"].append(dt.strftime("%A"))
    heat_map["hour"].append(dt.strftime("%H"))
    heat_map["chat_count"].append(1)

def increment_deleted():
    global deleted_message
    deleted_message += 1
"""
Self explained
"""
def parse_line(line, verbose):
    prefix = ""
    is_starting = is_starting_line(line)
    
    if is_starting:
        #Check wether the starting line is a chat or an event
        body = is_starting.group(18)
        chat = is_chat(body)
        dt = extract_timestamp(is_starting.group(2).replace(".", ":"))
        increment_heatmap(dt)
        
        if chat:
            has_attachment = contains_attachment(chat.group(3))
            increment_chat_count(chat.group(1))
            message_body = chat.group(3)
            
            
            if has_attachment:
                prefix = "@@@" 
                increment_attachment_count(has_attachment)
                
                if verbose: print(bcolors.OKBLUE + bcolors.HEADER + prefix + line)
                
            else:
                if is_deleted(message_body):
                    increment_deleted()
                else:
                    prefix = "+++"
                    
                    #URL & Domain
                    urls = extract_url(message_body)
                    if urls:
                        increment_link_count(urls)

                    #Emoji
                    emjs = extract_emojis(message_body)
                    
                    #Word Count & Wordcloud
                    get_words(message_body)
                
                    if verbose: print(bcolors.OKGREEN + bcolors.HEADER + prefix + line)
                
        elif is_event(body):
            prefix = "***"
                
            if verbose: print(bcolors.WARNING + prefix + line)
        
    else:
        prefix = "|||"
        
        #URL & Domain
        urls = extract_url(line)
        if urls:
            increment_link_count(urls)
        
        #Emoji    
        emjs = extract_emojis(line)
        
        #Word Count & Wordcloud
        get_words(line)

        if verbose: print(bcolors.FAIL + prefix + line)

print("Extracting data. Please wait....")

for line in content:
    parse_line(line, verbose)
    
print("Done. You can run next cell.")
# Out:
# REjbA
# |||
# |||Una vez apuntados os meteré en un grupito de los que van a participar mañana. Sí alguno necesita *Salvoconducto* lo gestionamos con Cáritas.
# |||
# |||Un fuerte abrazo
# |||
# |||Gleison
# ***[21/10/20, 22:39:37] +34 674 11 83 98 left
# ***[22/10/20, 15:44:33] Gleison added +34 645 85 67 76
# ***[22/10/20, 22:18:04] +34 601 05 51 98 added +34 653 89 90 99
# ***[22/10/20, 22:36:57] +34 601 05 51 98 added +34 650 93 94 86
# ***[22/10/20, 22:38:03] +34 601 05 51 98 added +34 610 17 87 56
# ***[22/10/20, 23:17:19] Gleison added +34 722 20 04 95
# ***[26/10/20, 01:44:41] +34 603 20 95 51 left
# +++[28/10/20, 20:29:14] Gleison: Muy buenas noches Voluntarios! Después de la tormenta de semana pasada creo que ni el estado de alarma nos impedirá de vernos mañana en el bocadillo solidario.
# |||
# |||Como viene siendo habitual aquí os dejo el link: https://forms.gle/QoGrBSVphXMNoL5r7
# |||Nos vemos mañana, Dios mediante.
# |||
# |||Un fuerte abrazo
# |||
# |||Gleison
# +++[28/10/20, 20:32:39] Gleison: Perdón por las las molestias
# +++[28/10/20, 20:32:48] Gleison: El problema técnico ya está solucionado
# ***[29/10/20, 22:00:44] +34 601 05 51 98 added +34 608 62 60 91
# ***[29/10/20, 22:01:52] +34 601 05 51 98 added Quique Vidal Flores
# ***[3/11/20, 22:29:41] +34 671 45 81 37 added +34 643 66 26 33
# +++[4/11/20, 17:58:49] Gleison: Buenas tardes, queridos voluntarios. En primer lugar bienvenidos los que habéis entrado al grupo esos dias.
# |||
# |||Puesto que todavía no nos confinan, *mañana saldremos* por las calles del centro a llevar algo de alimento pero sobre todo _calor humano a las personas sin Hogar_ que nos encontremos. Para ello ya sabéis tenéis que apuntaros aquí 👇🏽
# |||
# |||https://forms.gle/W9dh28oYtrBG1LvN6
# |||
# |||En cuanto sepamos quiénes estamos apuntados os meteremos en un grupito a parte para dar las siguientes informaciones.
# |||
# |||Para cualquier pregunta, dificultad etc...aquí me tenéis.
# |||
# |||Nos vemos mañana, Dios mediante.
# |||
# |||Gleison 😃
# ***[5/11/20, 14:35:31] +34 671 45 81 37 added +34 672 67 26 77
# ***[5/11/20, 17:28:53] +34 645 85 67 76 left
# +++[5/11/20, 18:22:30] +34 607 88 31 19: ID de la reunión: 93013093401. Código de acceso: 527822
# @@@[6/11/20, 17:05:01] Miguel Fernández Martín (Bocadillo Solidario): image omitted
# +++[6/11/20, 17:23:37] Miguel Fernández Martín (Bocadillo Solidario): https://youtu.be/VhTRpMZEdww
# ***[7/11/20, 08:56:42] Gleison added +34 645 85 67 76
# +++[9/11/20, 16:24:36] +34 601 05 51 98: 1. Sábado 14, 18-21h, Iglesia Calatravas (C/Alcalá 25, Metro: Sevilla/Sol)
# +++[9/11/20, 16:24:36] +34 601 05 51 98: Hola!!! Como sabéis, se acercan las recogidas estos dos findes próximos 😉
# +++[9/11/20, 16:24:37] +34 601 05 51 98: 2. Sábado 21, 12-15h, San Juan de la Cruz (Pza. San Juan de la Cruz, Metro: G. Marañón, N. Ministerios)
# +++[9/11/20, 16:24:37] +34 601 05 51 98: Quienes podáis echar una mano esos días, os paso links para que os unáis y coordinarlo 😉
# +++[9/11/20, 16:24:38] +34 601 05 51 98: Para el 1. (Calatravas, Sábado 14 por la tarde) https://chat.whatsapp.com/E5PQbwKlmq96UYBGacpfdG
# +++[9/11/20, 16:24:38] +34 601 05 51 98: Y para el 2. (San Juan de la Cruz, Sábado 21 por la mañana) https://chat.whatsapp.com/I4qtZw47x6oLQ860bfJ44i
# +++[9/11/20, 16:25:15] +34 601 05 51 98: Las recogidas para nadie sin conectar
# +++[9/11/20, 16:25:20] +34 601 05 51 98: Esto jajaja
# +++[11/11/20, 17:45:15] Gleison: Queridos voluntarios:  Esta semana no tendremos bocadillo solidario por una serie de imprevistos que se nos han surgido.
# |||¡Espero que podamos vernos la próxima semana Dios mediante!
# |||Un abrazo 😷 🙏
# ***[11/11/20, 17:45:46] +1 (787) 232‑5565 left
# ***[11/11/20, 17:58:48] +34 691 12 83 42 left
# @@@[13/11/20, 16:44:18] Miguel Fernández Martín (Bocadillo Solidario): image omitted
# +++[13/11/20, 16:45:21] Miguel Fernández Martín (Bocadillo Solidario): (en este grupo también podéis escribirme directamente para la b) jejeje 😉)
# ***[13/11/20, 17:39:35] +34 665 61 76 29 left
# ***[14/11/20, 11:18:59] +34 671 45 81 37 added +34 608 71 08 11
# +++[18/11/20, 20:25:05] Gleison: Buenas tardes, queridos Voluntarios!! Volvemos esa semana con el bocadillo solidario con muchísimas ganas. ¿Y como hago para apuntarme? aqui: https://forms.gle/fktsLkxq4knX73Uq5
# |||
# |||Os espero mañana, si el Señor nos los remedia.
# ***[18/11/20, 23:26:03] +34 601 22 61 30 left
# ***[20/11/20, 13:46:23] +34 675 04 59 17 added +34 633 94 51 03
# ***[20/11/20, 17:13:17] Drogo Diego Galileo left
# @@@[21/11/20, 11:28:41] Miguel Fernández Martín (Bocadillo Solidario): image omitted
# ***[21/11/20, 14:55:30] +34 601 05 51 98 added +34 610 08 03 47
# ***[22/11/20, 17:24:56] Miguel Peralta added +34 680 62 84 30
# +++[25/11/20, 19:52:45] Gleison: Buenas tardes queridos voluntarios! tengo la alegria de traeros el enlace para apuntarnos esa semana. Aqui lo tenéis: https://forms.gle/sYfrP8KzSELHvXou9
# +++[25/11/20, 19:52:45] Gleison: Nos vemos Dios mediante mañana!
# |||
# |||Un abrazo
# |||
# |||Gleison
# +++[26/11/20, 17:30:01] Miguel Peralta: Hola a todos! Para el reparto de hoy nos quedan 2 plazas libres!
# |||
# |||*2 PLAZAS* por si alguien se anima de última hora.
# ***[26/11/20, 18:20:59] +34 649 00 75 99 left
# ***[26/11/20, 18:59:33] +34 616 56 94 71 left
# ***[26/11/20, 21:03:01] +34 622 80 66 52 left
# ***[26/11/20, 22:46:39] +34 601 05 51 98 added +34 722 13 34 32
# +++[30/11/20, 16:46:15] Gleison: Muy buenas tardes, queridos voluntarios. Esa semana tenemos *encuentro doble*. Y el primero es *Mañana* porque habrá  una super adoración al Santísimo de  Jóvenes en la paróquia San Juan de la Cruz. Sí os parece nos uniremos a los jóvenes de la Politécnica,  con la intención de sencillamente rezar por las personas sin hogar, a las que semanalmente nos encontramos. El aforo del templo es enorme, así que podemos cumplir todas las medidas de distancia y aforos sin ningún problema. Es una oportunidad preciosa, para los que no podéis estar los jueves por temas de contagio y demás. A continuación os dejo el cartelito. Para cualquier cosa escribidme.
# @@@[30/11/20, 16:46:21] Gleison: image omitted
# +++[30/11/20, 16:47:26] Gleison: Lo otro es que este jueves nos vemos en el bocadillo solidario, próximamente os envío el enlace de siempre.
# |||Un abrazo muy grande
# |||
# |||Gleison 😃
# +++[2/12/20, 20:05:43] Gleison: Buenas tardes, queridos voluntarios! La adoración que hemos hecho algunos la noche de ayer ya nos ha calentado motores para la fría noche que nos espera mañana. Aquí tenéis el enlace para mañana: https://forms.gle/yNZoBMuZko1uwtf29
# |||
# |||A los que os vayas apuntando, os voy dando las siguientes indicaciones.
# |||
# |||Un abrazo muy grande
# |||Gleison
# ***[9/12/20, 13:21:58] +34 675 04 59 17 added +34 644 04 28 26
# +++[9/12/20, 20:13:51] Gleison: holaaa,  queridos voluntarios!! mañana saldremos a calentar algunos corazones, de algunas personas que están en el frio de la  calle.
# +++[9/12/20, 20:14:19] Gleison: Aqui teneis el enlace:https://forms.gle/dVobAtd6Xr7MSfbt8
# +++[9/12/20, 20:14:51] Gleison: Espero que estéis todos bien!
# |||Aqui me teneis para lo que necesiteis. un abrazo
# ***[10/12/20, 19:56:06] +34 645 85 67 76 left
# ***[10/12/20, 23:36:48] +34 601 05 51 98 added +34 675 30 70 97
# ***[11/12/20, 22:35:16] +34 671 45 81 37 added +34 642 55 88 67
# +++[16/12/20, 20:30:23] Gleison: Hola queridos Voluntarios!! Esa semana tenemos Bocadillo Especial de Navidad!!!! asi que la idea es dar nuestro amor y cariño, un buen bocadillo y deleitarlos con nuestros villancicos. ¿Qué os parece? asi que el que tenga una buena voz, muchas ganas será bienvenido. Si además toca la guitarra le acompañaré con mi cajón flamenco.
# |||
# |||Aquí tenéis el enlace para esa semana: https://forms.gle/Se6Uckwrxx8o4K9k8
# |||
# |||En esas noches frias y de lluvia nos da un poquito de pereza salir de casa, pero créanme que merece la pena el esfuerzo.
# |||
# |||Próximamente os hablaré del Nadie Sin Cenar 2020.
# |||
# |||Un abrazo
# |||Gleison
# +++[17/12/20, 22:27:14] +34 675 04 59 17: https://instagram.com/caritasmadriduniversitaria?igshid=82li3vwj2amv
# +++[18/12/20, 17:56:06] Gleison: Buenas tardes, queridos voluntarios. Hace unos instantes hemos lanzado el ¡¡¡nadie sin cenar 2020!!!
# |||
# |||Para apuntarse hay que tener un poquito de paciencia. Mandáis un correo a: nadiesincenar@caritasmadriduniversitaria.org
# |||
# |||Y *esperad la confirmación* se os pedirá rellenar un formulario, _sicut_ Bocadillo solidario, (por el tema del Covid y demás).
# |||
# |||Daros prisa que son solo 100 plazas.
# |||
# |||Feliz Navidad a Todos.
# |||
# |||Ya sabéis para que lo que haga falta, aquí me tenéis.
# |||
# |||Un abrazo
# |||
# |||Gleison
# +++[18/12/20, 18:51:53] +34 660 09 56 09: es enviar un correo diciendo que queremos apuntarnos? nada mas?
# +++[18/12/20, 18:52:17] +34 681 13 68 75: Sí, pero yo ya lo he mandado y no me han respondido aún
# +++[18/12/20, 18:52:27] +34 660 09 56 09: ni a mi ajajaaja
# +++[18/12/20, 18:52:31] Miguel Fernández Martín (Bocadillo Solidario): Esperar a que os respondan y ahí os indican 😉
# +++[18/12/20, 18:52:39] +34 660 09 56 09: vale genial!
# +++[18/12/20, 18:52:45] Miguel Fernández Martín (Bocadillo Solidario): Es que José Eugenio está que casi muere en el intento 🙈🤣
# @@@[18/12/20, 19:04:32] Gleison: image omitted
# ***[23/12/20, 10:28:12] +34 671 45 81 37 added +34 649 44 13 28
# ***[23/12/20, 22:29:30] +34 671 45 81 37 added +34 639 89 39 78
# ***[24/12/20, 11:44:48] +34 671 45 81 37 added +34 629 12 49 58
# ***[24/12/20, 18:16:08] +34 671 45 81 37 added +34 686 39 55 67
# ***[24/12/20, 18:27:12] +34 681 13 68 75 added +34 638 25 30 86
# ***[24/12/20, 19:59:32] Miguel Peralta added +34 660 17 47 67
# ***[24/12/20, 20:05:28] Miguel Peralta added +34 617 11 51 25
# ***[24/12/20, 20:05:49] Miguel Peralta added +34 638 57 74 49
# @@@[25/12/20, 03:32:11] Gleison: image omitted
# @@@[25/12/20, 20:34:39] Miguel Fernández Martín (Bocadillo Solidario): image omitted
# +++[26/12/20, 19:01:43] Miguel Fernández Martín (Bocadillo Solidario): Hola equipo!!! 🙌🏼🙌🏼 Desde Taizé Madrid y la Deleju nos han pedido ayuda a Cáritas Universitaria porque querían organizar mañana domingo un Bocadillo, como parte de un encuentro que van a hacer.
# |||
# |||Entonces nos piden si echamos una mano algunos de los que hayamos ido unas cuantas veces a Bocadillo.
# |||
# |||Quien pueda y se anime, que me escriba por priv. 💪🏼💪🏼 Sería mañana de 17 a 20h aprox. en San Juan de la Cruz
# |||
# |||Muchas gracias por la ayuda!!!!! 😊😊
# ***[28/12/20, 17:40:57] Gleison added +34 685 04 32 02
# ***[28/12/20, 17:41:05] Gleison added +34 627 47 78 94
# ***[28/12/20, 17:41:15] Gleison added +34 644 87 25 90
# @@@[1/1/21, 00:41:30] Gleison: image omitted
# +++[1/1/21, 00:51:19] +34 660 09 56 09: Que bonito!!!! Feliz año!!!!
# @@@[1/1/21, 01:42:33] Pablo Serafín Pastoral: sticker omitted
# @@@[1/1/21, 01:49:14] Miguel Fernández Martín (Bocadillo Solidario): sticker omitted
# +++[2/1/21, 12:39:26] Miguel Fernández Martín (Bocadillo Solidario): https://youtu.be/vMEhaEITp2M
# +++[9/1/21, 13:09:34] Miguel Fernández Martín (Bocadillo Solidario): Buenos días, equipo!!! 🌨️☃️
# |||Nos piden desde Cáritas Madrid y la Delegación de Jóvenes si habría alguien disponible por el centro (o cerca de un Metro que le pueda llevar fácil).
# |||Hay personas sin hogar que siguen por las rutas que solemos ir, sin el abrigo adecuado, y sin albergue. ❄️❄️
# |||La idea es ir a preguntar si necesitan algo. En CEDIA ahora hay algunas plazas libres. Y si necesitan abrigo, se lo buscamos. 🧥
# |||Si alguien pudiera, que me escriba por priv, porfa, para coordinarlo. Muchísimas gracias!!!! 😊😊
# +++[9/1/21, 15:38:26] +34 660 09 56 09: Yo estoy disponible!!!
# +++[9/1/21, 15:38:34] +34 660 09 56 09: Estoy al lado del metro de moncloa y me deja en sol directo
# +++[11/1/21, 21:33:43] Miguel Fernández Martín (Bocadillo Solidario): Quien tenga la TV a mano, que ponga TRECE 😉
# +++[11/1/21, 21:34:33] Miguel Fernández Martín (Bocadillo Solidario): Nuestra compañera @34660095609 sale hablando de la realidad de las personas sin hogar, en mitad de este temporal 🥳
# +++[11/1/21, 21:34:45] +34 647 95 72 09: Gracias! Esta Jesús 🤗
# +++[11/1/21, 21:35:03] +34 647 95 72 09: De San Egidio!
# +++[11/1/21, 21:35:13] Miguel Fernández Martín (Bocadillo Solidario): Luego va Carmela jejeje
# +++[11/1/21, 21:35:14] +34 647 95 72 09: Después Carmela? Qué bien!!!
# +++[11/1/21, 21:38:08] +34 660 09 56 09: Mañana!!
# +++[11/1/21, 21:38:16] +34 660 09 56 09: Es mañana al final ajajajaj
# +++[11/1/21, 21:38:43] +34 647 95 72 09: Vale! Muy bien!
# +++[11/1/21, 22:10:59] +34 681 13 68 75: ¿A qué hora se va a emitir? Para veros
# +++[11/1/21, 22:45:54] Miguel Fernández Martín (Bocadillo Solidario): Bueno, solo Carmela jejeje Las entrevistas que están haciendo son solo a 1
# +++[11/1/21, 22:46:08] Miguel Fernández Martín (Bocadillo Solidario): Es TRECE al día, que es de 21:00h a 22:00h
# +++[11/1/21, 22:46:35] Miguel Fernández Martín (Bocadillo Solidario): Pero la sección Fuera de Foco, que es donde va a salir, creo que es sobre 21:30h
# ***[12/1/21, 10:15:46] +34 671 45 81 37 added +34 634 10 03 54
# +++[12/1/21, 21:28:20] Miguel Fernández Martín (Bocadillo Solidario): Carmela en TRECE 😉
# @@@[12/1/21, 21:29:29] Miguel Fernández Martín (Bocadillo Solidario): image omitted
# +++[12/1/21, 21:42:43] +34 647 95 72 09: 👏🏻👏🏻👏🏻
# ***[13/1/21, 23:36:44] +34 662 16 27 54 left
# ***[14/1/21, 22:10:24] +34 658 70 87 93 left
# +++[15/1/21, 13:22:29] Gleison: Buenos días, queridos Voluntarios. Ayer retomamos nuestra andadura por las calles frías de Madrid en búsqueda de personas sin hogar. Fue una noche ciertamente mágica.
# +++[15/1/21, 13:23:40] Gleison: Bien pues, el mensaje que os quiero decir hoy, lo tendré que abreviarlo muchísimo. Pero el contexto es este: una de las voluntarias de este grupo, desde hace algún tiempo, tiene Leucemia y actualmente está esperando el transplante de médula ósea.
# |||
# |||Esa noticia me afectó mucho, como lo podéis imaginar. Por ello he decido apuntarme al banco de donantes de médula ósea. Consiente de que esa chica es una de las miles de personas que están en esa situación y que necesitan de esa ayuda. De esa vida. Y yo puedo ser esa ayuda, esa vida.
# +++[15/1/21, 13:24:14] Gleison: Os invito, a que cada uno vea sus posibilidades, y  considere aunar esfuerzos conmigo en pro de salvar esas vidas.
# +++[15/1/21, 13:24:38] Gleison: Para más info: https://www.fcarreras.org/es/donamedula
# +++[15/1/21, 13:25:11] Gleison: Pero sobre todo aquí estoy para cualquier pregunta que se os susciten.
# |||Un abrazo muy grande
# |||
# |||Gleison
# +++[15/1/21, 17:32:26] +34 647 95 72 09: Muchas gracias Gleison por la iniciativa, es una manera de solidaridad muy concreta. La otra es la oración, y nos comprometemos a ello.
# @@@[19/1/21, 12:39:29] Miguel Peralta: image omitted
# +++[19/1/21, 12:39:51] Miguel Peralta: Buenos días a todos, hoy vamos a romper un poco nuestra regla de no spam.
# |||Hoy es un día de celebración para todos los que alguna vez hemos pasado por Bocadillo Solidario. Hoy todos celebramos el cumpleaños de nuestro increíble líder. Hoy es el *cumpleaños de Glesion.*
# |||Hoy celebramos su increíble sonrisa, su preocupación por que cada voluntario este cómodo, sus rutas a paso rápido, sus esfuerzos por mejor día a día la actividad y aprenderse el nombre de todos, su enorme corazón.
# |||Hoy podemos aprovechar para felicitarle por sus 27 añazos. Hacer un hueco en nuestras oraciones para pedir por él, para que Dios le siga protegiendo y tenerle presente para que con su ejemplo aprendamos a hacer de nuestras vidas una entrega de amor a los demás.
# +++[19/1/21, 12:40:19] +34 675 04 59 17: MUCHISIMAS FELICIDADES!! @34651977580
# +++[19/1/21, 12:40:45] +34 650 04 62 21: ¡¡Feliz cumpleaños!!
# |||🎉🎂🎂🎉
# +++[19/1/21, 12:42:01] +34 601 05 51 98: FELICIDADES🥳
# +++[19/1/21, 12:43:42] +34 671 45 81 37: FELICIDADES @34651977580 !!!!!🥳🥳🥳🥳
# ***[19/1/21, 12:44:15] +34 606 71 58 59 left
# +++[19/1/21, 12:55:12] +34 660 09 56 09: 🙌🏼🙌🏼🙌🏼
# ***[19/1/21, 12:57:51] +34 686 92 42 53 left
# +++[20/1/21, 19:44:21] Gleison: Buenas noches, queridos voluntarios. Unámonos en solidaridad y recemos por las víctimas y sus familias de la explosión del edificio de la Paloma esa tarde, como habréis visto.
# |||
# |||El clima nos quiere echar para tras pero no será la lluvia todavía lo que nos detendrá de salir por las calles de Madrid mañana. Aqui tenéis el enlace para os podáis apuntar:https://forms.gle/STnGmJZ28ngXowB1A
# |||
# |||¡Aviso importante! por el toque de queda, vamos a adelantar la actividad en una hora. Es decir. Nos vemos en la Iglesia de las calatravas para preparar los alimentos a las 19h30. Para que podamos salir como tarde a las 20h. Y así podamos terminar antes y volver a casa sin problemas. Alguno me dirá: pero Gleison no llego a las 19h30 sino a las 20h. Estupendo, te indicaré la ruta y con quien vas. Te pones en contacto con el jefe de turno y listo.
# |||
# |||2º aviso. Como semana pasada en el enlace, los que necesitáis salvoconductos lo indicáis en el formulario y lo tramitamos.
# |||
# |||Creo que no me dejo nada en el tintero.
# |||
# |||Un abrazo muy grande a todos.
# |||
# |||Gleison
# +++[26/1/21, 18:11:06] Gleison: Queridos Voluntarios. La situación tan delicada que nos rodea, exige de nosotros cada vez más ajustarnos a las nuevas medidas de las autoridades. En este sentido, hemos decidido adelantar un poquito la actividad a las *19h*  para preparar las cosas, salir sobre las *19h40* y terminar la actividad a las *20h30*. De este modo esperamos poder preparar las cosas, estar con las personas sin hogar y volver a nuestras casas sin apenas prisas puesto que "bajo el cielo para todo hay un tiempo" (Ecle 3,7l
# |||
# |||Animo con los exámenes. 🤓💪🏽
# |||
# |||Mañana os paso el enlace, Dios mediante.
# |||
# |||Gleison
# +++[27/1/21, 16:23:16] Gleison: Buenas tardes, queridos Voluntarios! Conforme lo dicho ayer recuerdo que mañana nos veremos 19h para preparar cosas y demás. Pero ya sé que alguno llegará justito. Bueno eso se puede ir viendo según cada caso. Lo más normal es que alguno tenga que incorporarse ya in situ para hacer el voluntariado con su grupo.
# |||
# |||Aquí os dejo el enlace: https://forms.gle/YHjLqv6iSCcTsfXj7
# |||
# |||Mientras tenemos la oportunidad de salir es bueno aprovechar estos dias. Os comento que esta semana no haré un grupito sino que me pondré en contacto con los que os hayas apuntado personalmente con una listita de difusión. Así mismo que se pueden conseguir salvoconductos...
# |||
# |||Nos vemos mañana, Dios mediante.
# |||
# |||Un abrazo muy grande.
# |||
# |||Gleison
# Done. You can run next cell.

# %%
"""
DataFrame
"""
chat_per_member = (pd.DataFrame(member_chat)
                     .groupby(["member"])
                     .sum()
                     .sort_values(by = ['chat_count'], ascending=False))
popular_words_df = sorted(popular_words.items(), key=operator.itemgetter(1), reverse=True)
domains = (pd.DataFrame(refered_web)
                     .groupby(["domain"])
                     .sum()
                     .sort_values(by = ['d_count'], ascending=False))
emojis_df = (pd.DataFrame(emojis)
                     .groupby(["emj_char"])
                     .sum()
                     .sort_values(by = ['char_count'], ascending=False))
top_repeated_emoji = (pd.DataFrame(emojis)
                     .sort_values(by = ['char_count'], ascending=False))
heatmap_df = pd.DataFrame(heat_map)
grouped_heatmap = heatmap_df.groupby(["day", "hour"]).sum().sort_values(by=["chat_count"], ascending=False)
pivoted_heatmap = pd.pivot_table(grouped_heatmap, values='chat_count', index=['day'], columns=['hour'])

print("Done. You can run next cell.")
# Out:
# Done. You can run next cell.

# %%
"""
Top Member Chat
"""
top_member = chat_per_member.head(20)
if not top_member.empty:
    sns.set()
    member_plot = top_member.plot(kind='bar', legend=None, title="Top 20 active member", figsize=(18, 6), color="purple")
    member_plot.set_xlabel("Member (phone number/contact name)")
    member_plot.set_ylabel("Chat Count")
    for i, v in enumerate(top_member["chat_count"]):
        member_plot.text(i - .15, v + 3, v, color="#004d40")
else:
    print("This chat has no member")

# %%
"""
Heatmap
"""
heatmap_df = pd.DataFrame(heat_map)
if not heatmap_df.empty:
    grouped_heatmap = heatmap_df.groupby(["day", "hour"]).sum().sort_values(by=["chat_count"], ascending=False)
    pivoted_heatmap = pd.pivot_table(grouped_heatmap, values='chat_count', index=['day'], columns=['hour'])
    plt.figure(figsize = (16,5))
    sns.heatmap(pivoted_heatmap, 
                annot=True, 
                fmt=".0f", 
                linewidths=.2,
                cmap="YlGnBu",
                cbar=False
               )
else:
    print("This chat does not contain any datetime")

# %%
s_attachments = sorted(attachments.items(), key = operator.itemgetter(1), reverse=True)
if s_attachments:
    at_labels = [x[0].title() + " " + str(x[1]) for x in s_attachments]

    at_explode = tuple([0 + i * 0.1 for i in range(len(s_attachments))])
    at_sizes = [x[1] for x in s_attachments]
    at_colors = ["#FF6D00", "#64DD17", "#00B8D4", "#304FFE", "#AA00FF", "#d50000", "#546E7A", "#dddddd"]
    at_pie = plt.pie(at_sizes,  
             autopct='%1.1f%%',
             explode=at_explode,
             pctdistance=1.2,
             colors=at_colors,
             startangle=160,
             radius=1.3,
             wedgeprops = { 'linewidth' : 2, 'edgecolor' : 'white' },
    )

    at_centre_circle = plt.Circle((0,0),0.85,color='white', fc='white',linewidth=1.25)
    at_fig = plt.gcf()
    at_fig.gca().add_artist(at_centre_circle)

    plt.legend(
        loc='upper left',
        labels=at_labels,
        prop={'size': 11},
        bbox_to_anchor=(1, 1)
    )
    at_axis = plt.axis('equal')
else:
    print("This chat contains no attachment.")

# %%
"""
Top Website
"""
top_web = domains.head(20).sort_values("d_count")
if not top_web.empty:
    mpl.rc('font', **{'sans-serif' : 'arial', 'family' : 'sans-serif'})
    web_plot = top_web.plot(kind='barh', legend=None, title="Top 20 mentioned domain", figsize=(20,10), color="#1de9b6")
    web_plot.set_xlabel("Mention Count")
    for i, v in enumerate(top_web["d_count"]):
        web_plot.text(1, i - .15, v, color="purple")
else:
    print("This chat not contains any link")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
"""
Wordcloud
"""
if chat_words:
    wordcloud = WordCloud(
        width = 1000, 
        height = 500,
        background_color = "white"
    ).generate(chat_words)

    plt.figure(figsize=(15,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
else:
    print("This chat contains no word")

# %%
"""
Raw Output
"""
print("\n=======================================\n")
print("#Total Chat: {0}".format(total_chat))
print("#Deleted Message: {0}".format(deleted_message))
print("#Total Attachment: {0}".format(sum([x[1] for x in s_attachments])))
for a in s_attachments:
    print("  - : {0}".format(a))
    


print("\n#Top 20 Member")
print("-----------------")
print(top_member)


print("\n#Top 20 Words")
print("-----------------")
for k, v in enumerate(popular_words_df):
    if k < 20:
        print(v)
    else:
        break
        
print("\n#Top 20 Emoji")
print("-----------------")
print(emojis_df.head(20))

print("\n#Top 20 Mentioned Website")
print("-----------------")
print(top_web.sort_values("d_count", ascending=False))
# Out:
# =======================================
#
# #Total Chat: 113
# #Deleted Message: 2
# #Total Attachment: 15
#   - : ('image', 13)
#   - : ('sticker', 2)
#
# #Top 20 Member
# -----------------
#                                                chat_count
# member
# Gleison                                                34
# Miguel Fernández Martín (Bocadillo Solidario)          25
# +34 660 09 56 09                                       10
# +34 601 05 51 98                                        9
# +34 671 45 81 37                                        7
# +34 647 95 72 09                                        6
# Pablo Serafín Pastoral                                  4
# +34 636 39 31 56                                        4
# Miguel Peralta                                          3
# +34 609 10 21 13                                        2
# +34 675 04 59 17                                        2
# +34 681 13 68 75                                        2
# +34 671 26 47 95                                        1
# +34 601 19 90 64                                        1
# +34 650 04 62 21                                        1
# +34 607 88 31 19                                        1
# Voluntariado                                            1
#
# #Top 20 Words
# -----------------
# ('que', 107)
# ('de', 106)
# ('el', 74)
# ('a', 69)
# ('la', 52)
# ('en', 47)
# ('para', 45)
# ('y', 44)
# ('un', 40)
# ('las', 39)
# ('por', 33)
# ('os', 32)
# ('nos', 31)
# ('es', 27)
# ('con', 23)
# ('maana', 22)
# ('una', 21)
# ('los', 21)
# ('gleison', 20)
# ('sin', 18)
#
# #Top 20 Emoji
# -----------------
# Empty DataFrame
# Columns: [char_count]
# Index: []
#
# #Top 20 Mentioned Website
# -----------------
#                    d_count
# domain
# forms.gle               15
# chat.whatsapp.com        2
# youtu.be                 2
# goo.gl                   1
# instagram.com            1
# www.fcarreras.org        1
